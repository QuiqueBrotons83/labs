# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Filtrado de Datos
#
# En este laboratorio usaremos el DataFrame creado en la lección anterior resultado de la unión de los conjuntos de datos compartidos contigo.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.

# %%
# Lo primero que hacemos es importar las librerias Panda y Numpy. Y hacemos que se muuestren los anchos de columna.
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
datos_netflix_filtros = pd.read_csv("datos/datos_netflix.csv", index_col = 0)
datos_netflix_filtros.head(3)
# Out:
#   show_id     type                 Title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water      Desconocido
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                        Desconocido  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA        NaN
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %% [markdown]
# #### Ejercicio 1: ¿Cuáles son todos los títulos lanzados en 2021 que son del tipo 'Movie'?

# %%
titulos_2021 = datos_netflix_filtros[(datos_netflix_filtros['release_year'] == 2021) & (datos_netflix_filtros['type'] == 'Movie')]
titulos_2021
# Out:
#      show_id   type                                              Title  \
# 6         s7  Movie                   My Little Pony: A New Generation
# 9        s10  Movie                                       The Starling
# 12       s13  Movie                                       Je Suis Karl
# 13       s14  Movie                   Confessions of an Invisible Girl
# 18       s19  Movie                                          Intrusion
# ...      ...    ...                                                ...
# 1425   s1426  Movie                        Creating The Queen's Gambit
# 1431   s1432  Movie                                        Stuck Apart
# 1436   s1437  Movie  Ratones Paranoicos: The Band that Rocked Argen...
# 1466   s1467  Movie                       The Minimalists: Less Is Now
# 1468   s1469  Movie                          What Happened to Mr. Cha?
#
#                              director  \
# 6       Robert Cullen, José Luis Ucha
# ...

# %% [markdown]
# #### Ejercicio 2: ¿Qué títulos tienen una duración de 90 minutos? Muestra solo las columnas de título y de duración.

# %%
duracion_noventa = datos_netflix_filtros[datos_netflix_filtros['duration'] == '90 min']
duracion_noventa[['Title', 'duration']]
# Out:
#                                 Title duration
# 0                Dick Johnson Is Dead   90 min
# 94                          Show Dogs   90 min
# 107                  A Champion Heart   90 min
# 229                      The Old Ways   90 min
# 283              Misha and the Wolves   90 min
# ...                               ...      ...
# 8651                            Tyson   90 min
# 8655             Unaccompanied Minors   90 min
# 8670                    Vantage Point   90 min
# 8735  Who's That Knocking at My Door?   90 min
# 8776                       Yellowbird   90 min
#
# [152 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 3: ¿Cuáles son todos los títulos del país 'India' lanzados después de 2018?

# %%
india_lanzados = datos_netflix_filtros[(datos_netflix_filtros['country'] == 'India') & (datos_netflix_filtros['release_year'] == 2018)]
india_lanzados
# Out:
#      show_id     type                               Title            director  \
# 541     s542    Movie                    Truckbhar Swapna        Pramod Pawar
# 892     s893    Movie            Tottaa Pataaka Item Maal    Aditya Kripalani
# 2015   s2016    Movie                         Aapla Manus      Satish Rajwade
# 2016   s2017    Movie       Ani... Dr. Kashinath Ghanekar  Abhijeet Deshpande
# 2019   s2020    Movie                               Cycle       Prakash Kunte
# ...      ...      ...                                 ...                 ...
# 8235   s8236  TV Show                         The Calling               Bumpy
# 8267   s8268    Movie  The Dark Side of Life: Mumbai City          Tariq Khan
# 8672   s8673    Movie                   Veerey Ki Wedding         Ashu Trikha
# 8683   s8684    Movie                       Vodka Diaries   Kushal Srivastava
# 8775   s8776  TV Show                     Yeh Meri Family         Desconocido
#
# ...

# %% [markdown]
# #### Ejercicio 4: ¿Qué títulos tienen clasificación 'TV-14' o 'R'?

# %%
clasificacion = datos_netflix_filtros[datos_netflix_filtros['rating'].isin(['TV-14', 'R'])]
clasificacion['Title']
# Out:
# 8                         The Great British Baking Show
# 18                                            Intrusion
# 20      Monsters Inside: The 24 Faces of Billy Milligan
# 21                               Resurrection: Ertugrul
# 24                                                Jeans
#                              ...
# 8794                                             اشتباك
# 8799                                              Zenda
# 8802                                             Zodiac
# 8804                                         Zombieland
# 8806                                             Zubaan
# Name: Title, Length: 2959, dtype: object

# %% [markdown]
# #### Ejercicio 5: ¿Cuáles son los títulos dirigidos por 'Christopher Nolan' o 'Martin Scorsese'? ¿Cuántos a dirigido cada uno de los directores?

# %%
directores =datos_netflix_filtros[datos_netflix_filtros['director'].isin(['Christopher Nolan', 'Martin Scorsese'])]
directores
# Out:
#      show_id   type                                              Title  \
# 340     s341  Movie                                          Inception
# 1358   s1359  Movie                                     Shutter Island
# 2632   s2633  Movie                       No Direction Home: Bob Dylan
# 2860   s2861  Movie                                               Hugo
# 3227   s3228  Movie                                       The Irishman
# 3759   s3760  Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 6111   s6112  Movie                    Alice Doesn't Live Here Anymore
# 6826   s6827  Movie                                  Gangs of New York
# 6880   s6881  Movie                                         GoodFellas
# 7431   s7432  Movie                                       Mean Streets
# 7820   s7821  Movie                                        Raging Bull
# 8272   s8273  Movie                                       The Departed
# ...

# %%
directores['director'].value_counts()
# Out:
# director
# Martin Scorsese      12
# Christopher Nolan     1
# Name: count, dtype: int64

# %% [markdown]
# #### Ejercicio 6: ¿Qué títulos pertenecen a los países 'United States', 'United Kingdom' o 'Canada'? Dentro de estos países, ¿cuántas películas tienen más de un lenguaje?

# %%
titulos_paises = datos_netflix_filtros[datos_netflix_filtros['country'].isin(['United States','United Kingdom', 'Canada'])]
titulos_paises[['Title', 'country', 'Language']]
# Out:
#                               Title         country Language
# 0              Dick Johnson Is Dead   United States  English
# 8     The Great British Baking Show  United Kingdom      NaN
# 9                      The Starling   United States      NaN
# 15                Dear White People   United States      NaN
# 27                        Grown Ups   United States      NaN
# ...                             ...             ...      ...
# 8791                    Young Adult   United States      NaN
# 8793           Yours, Mine and Ours   United States      NaN
# 8802                         Zodiac   United States      NaN
# 8804                     Zombieland   United States      NaN
# 8805                           Zoom   United States      NaN
#
# [3418 rows x 3 columns]

# %%
titulos_lenguaje = titulos_paises[titulos_paises['Language'].str.contains(',', na=False)]
titulos_lenguaje
# No hay más de un lenguaje en estos titulos.
# Out:
# Empty DataFrame
# Columns: [show_id, type, Title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Genre, Premiere, Runtime, IMDB Score, Language, original]
# Index: []

# %% [markdown]
# #### Ejercicio 7: ¿Qué títulos fueron lanzados entre 2015 y 2020, inclusive?

# %%
datos_netflix_filtros[datos_netflix_filtros['release_year'].between(2015, 2020, inclusive='both')]
# Out:
#      show_id     type                                              Title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17       s18  TV Show                                    Falsa identidad
# 21       s22  TV Show                             Resurrection: Ertugrul
# 32       s33  TV Show                                      Sex Education
# ...      ...      ...                                                ...
# 8796   s8797  TV Show                                         Yunus Emre
# 8797   s8798  TV Show                                          Zak Storm
# 8801   s8802    Movie                                            Zinzana
# 8803   s8804  TV Show                                        Zombie Dumb
# 8806   s8807    Movie                                             Zubaan
#
#                                            director  \
# ...

# %% [markdown]
# #### Ejercicio 8: ¿Cuáles son los títulos cuya puntuación en IMDb está entre 6.5 y 8.0 y que no sepamos cual es su duración?

# %%
datos_netflix_filtros[datos_netflix_filtros['IMDB Score'].between(6.5, 8.0, inclusive='both') & datos_netflix_filtros['duration'].isnull()]
# Out:
#      show_id   type                        Title  \
# 834     s835  Movie                 Blue Miracle
# 895     s896  Movie                       Oxygen
# 910     s911  Movie                      Monster
# 1024   s1025  Movie       Arlo the Alligator Boy
# 1157   s1158  Movie                     Bad Trip
# ...      ...    ...                          ...
# 5783   s5784  Movie               Audrie & Daisy
# 5840   s5841  Movie   The Fundamentals of Caring
# 5849   s5850  Movie              Team Foxcatcher
# 5901   s5902  Movie                          Tig
# 5906   s5907  Movie  What Happened, Miss Simone?
#
#                            director  \
# 834                  Julio Quintana
# 895                   Alexandre Aja
# 910                 Anthony Mandler
# 1024                     Ryan Crego
# 1157                    Desconocido
# ...                             ...
# 5783         Bonni Cohen, Jon Shenk
# 5840                    Rob Burnett
# 5849                 Jon Greenhalgh
# ...

# %% [markdown]
# #### Ejercicio 9: ¿Cuáles son las películas cuya duración de 90 y 150 minutos?

# %%
datos_netflix_filtros[datos_netflix_filtros['duration'].isin(['90 min', '150 min'])]
# Out:
#      show_id   type                              Title             director  \
# 0         s1  Movie               Dick Johnson Is Dead      Kirsten Johnson
# 94       s95  Movie                          Show Dogs         Raja Gosnell
# 107     s108  Movie                   A Champion Heart         David de Vos
# 205     s206  Movie  Kyo Kii... Main Jhuth Nahin Bolta         David Dhawan
# 229     s230  Movie                       The Old Ways  Christopher Alender
# ...      ...    ...                                ...                  ...
# 8651   s8652  Movie                              Tyson         James Toback
# 8655   s8656  Movie               Unaccompanied Minors            Paul Feig
# 8670   s8671  Movie                      Vantage Point          Pete Travis
# 8735   s8736  Movie    Who's That Knocking at My Door?      Martin Scorsese
# 8776   s8777  Movie                         Yellowbird    Christian De Vita
#
# ...

# %% [markdown]
# #### Ejercicio 10: ¿Cuáles son los títulos que contienen la palabra 'Love' en su título y que sean de tipo TV Show?

# %%
titulos_love = datos_netflix_filtros[(datos_netflix_filtros['Title'].str.contains('Love', case=False,na=False)) & (datos_netflix_filtros['type'] == 'TV Show')]
titulos_love
# Out:
#      show_id     type                               Title     director  \
# 25       s26  TV Show                Love on the Spectrum  Desconocido
# 659     s660  TV Show     Bangkok Love Stories: Innocence  Desconocido
# 731     s732  TV Show     Love (ft. Marriage and Divorce)  Desconocido
# 883     s884  TV Show                Love, Death & Robots  Desconocido
# 1032   s1033  TV Show                        Love Naggers  Desconocido
# ...      ...      ...                                 ...          ...
# 7632   s7633  TV Show  O-Negative, Love Can’t Be Designed  Desconocido
# 7892   s7893  TV Show                  Roonpi Secret Love  Desconocido
# 8567   s8568  TV Show      The Year of Happiness and Love  Desconocido
# 8575   s8576  TV Show                     This Is My Love  Desconocido
# 8721   s8722  TV Show                       What Is Love?  Desconocido
#
#                                                    cast        country  \
# ...

# %% [markdown]
# #### Ejercicio 11: ¿Cuáles son los títulos en los que el director tiene el apellido 'Johnson'?

# %%
director_apellido = datos_netflix_filtros[(datos_netflix_filtros['director'].str.contains('Johnson', case=False,na=False))]
director_apellido[['Title', 'director']]
# Out:
#                                        Title                         director
# 0                       Dick Johnson Is Dead                  Kirsten Johnson
# 829                         Dog Gone Trouble                    Kevin Johnson
# 846                                     Home                      Tim Johnson
# 2052                        Love, Guaranteed              Mark Steven Johnson
# 2083                    The Debt Collector 2                 Jesse V. Johnson
# 2455                              The Stolen                    Niall Johnson
# 2496                               Honeytrap                  Rebecca Johnson
# 3511                              Avengement                 Jesse V. Johnson
# 3717                           Triple Threat  Jesse V. Johnson, Jesse Johnson
# 4033                                 Juanita                    Clark Johnson
# 4661                      The Debt Collector                 Jesse V. Johnson
# ...

# %% [markdown]
# #### Ejercicio 12: ¿Tenemos algún documental ('Documentaries') de Mike Tyson?

# %%
documental_myke = datos_netflix_filtros[(datos_netflix_filtros['listed_in'] == 'Documentaries') & (datos_netflix_filtros['Title'].str.contains('Tyson', case=False,na=False))]
documental_myke[['type', 'Title']]

# No hay documentales de Myke Tyson
# Out:
# Empty DataFrame
# Columns: [type, Title]
# Index: []

# %% [markdown]
# #### Ejercicio 13: Selecciona solo las columnas 'title', 'country' y 'release_year' del dataset.

# %%
datos_netflix_filtros[['Title','country','release_year']]
# Out:
#                       Title        country  release_year
# 0      Dick Johnson Is Dead  United States          2020
# 1             Blood & Water   South Africa          2021
# 2                 Ganglands            NaN          2021
# 3     Jailbirds New Orleans            NaN          2021
# 4              Kota Factory          India          2021
# ...                     ...            ...           ...
# 8802                 Zodiac  United States          2007
# 8803            Zombie Dumb            NaN          2018
# 8804             Zombieland  United States          2009
# 8805                   Zoom  United States          2006
# 8806                 Zubaan          India          2015
#
# [8807 rows x 3 columns]

# %% [markdown]
# #### Ejercicio 14: Filtra las columnas que contienen la palabra 'date'.

# %%
filtro_date = datos_netflix_filtros.filter(like='date')
filtro_date
# Out:
#               date_added
# 0     September 25, 2021
# 1     September 24, 2021
# 2     September 24, 2021
# 3     September 24, 2021
# 4     September 24, 2021
# ...                  ...
# 8802   November 20, 2019
# 8803        July 1, 2019
# 8804    November 1, 2019
# 8805    January 11, 2020
# 8806       March 2, 2019
#
# [8807 rows x 1 columns]

# %% [markdown]
# #### Ejercicio 15: Usando `query()`, filtra todos los títulos del país 'France' con una duración de 80 minutos.

# %%
datos_netflix_filtros.query('country == "France" and duration == "80 min"')
# Out:
#      show_id   type Title            director  \
# 5474   s5475  Movie  Arès  Jean-Patrick Benes
#
#                                                    cast country    date_added  \
# 5474  Ola Rapace, Micha Lescot, Thierry Hancisse, Hé...  France  May 23, 2017
#
#       release_year rating duration  \
# 5474          2016  TV-MA   80 min
#
#                                               listed_in  \
# 5474  Action & Adventure, International Movies, Sci-...
#
#                                             description Genre Premiere  \
# 5474  A futuristic France tries to keep its people f...   NaN      NaN
#
#       Runtime  IMDB Score Language original
# 5474      NaN         NaN      NaN      NaN

# %% [markdown]
# #### Ejercicio 16: Filtra los títulos que son películas ('Movie') y fueron lanzados antes de 2010.

# %%
datos_netflix_filtros.query('type == "Movie" and release_year < 2010')
# Out:
#      show_id   type                 Title          director  \
# 7         s8  Movie               Sankofa      Haile Gerima
# 22       s23  Movie       Avvai Shanmughi    K.S. Ravikumar
# 24       s25  Movie                 Jeans        S. Shankar
# 26       s27  Movie        Minsara Kanavu       Rajiv Menon
# 41       s42  Movie                  Jaws  Steven Spielberg
# ...      ...    ...                   ...               ...
# 8793   s8794  Movie  Yours, Mine and Ours      Raja Gosnell
# 8799   s8800  Movie                 Zenda    Avadhoot Gupte
# 8802   s8803  Movie                Zodiac     David Fincher
# 8804   s8805  Movie            Zombieland   Ruben Fleischer
# 8805   s8806  Movie                  Zoom      Peter Hewitt
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %% [markdown]
# #### Ejercicio 17: Encuentra los 10 títulos con las puntuaciones más altas en IMDb.

# %%
datos_netflix_filtros.nlargest(10, "IMDB Score")
# Out:
#      show_id   type                                        Title  \
# 1886   s1887  Movie     David Attenborough: A Life on Our Planet
# 4293   s4294  Movie                      Springsteen on Broadway
# 5893   s5894  Movie  Winter on Fire: Ukraine's Fight for Freedom
# 3386   s3387  Movie                       Dancing with the Birds
# 5152   s5153  Movie                       Cuba and the Cameraman
# 1171   s1172  Movie                                   Seaspiracy
# 1857   s1858  Movie        The Three Deaths of Marisela Escobedo
# 3273   s3274  Movie                                        Klaus
# 2038   s2039  Movie                           My Octopus Teacher
# 2097   s2098  Movie                               Rising Phoenix
#
#                                                director  \
# 1886  Alastair Fothergill, Jonnie Hughes, Keith Scholey
# 4293                                         Thom Zimny
# 5893                                  Evgeny Afineevsky
# ...

# %% [markdown]
# #### Ejercicio 18: Encuentra los 5 títulos con las puntuaciones más bajas en IMDb.

# %%
datos_netflix_filtros.nsmallest(5, "IMDB Score")
# Out:
#      show_id   type            Title                   director  \
# 3623   s3624  Movie  Enter the Anime              Alex Burunova
# 2104   s2105  Movie      Dark Forces          Bernardo Arellano
# 3094   s3095  Movie          The App               Elisa Fuksas
# 5073   s5074  Movie   The Open House  Matt Angel, Suzanne Coote
# 1777   s1778  Movie      Kaali Khuhi            Terrie Samundra
#
#                                                    cast  \
# 3623  Kozo Morishita, Yoko Takahashi, Shinji Aramaki...
# 2104  Tenoch Huerta, Eréndira Ibarra, Dale Carley, A...
# 3094  Vincenzo Crea, Jessica Cressy, Greta Scarano, ...
# 5073  Dylan Minnette, Piercey Dalton, Patricia Bethu...
# 1777  Shabana Azmi, Leela Samson, Sanjeeda Sheikh, S...
#
#                     country         date_added  release_year rating duration  \
# 3623   United States, Japan     August 5, 2019          2019  TV-MA   59 min
# 2104                 Mexico    August 21, 2020          2020  TV-MA   81 min
# ...

# %% [markdown]
# #### Ejercicio 19: Filtra todos los títulos que no tienen un director asignado (valores nulos en la columna 'director').

# %%
datos_netflix_filtros[datos_netflix_filtros['director'].isnull()]

# Aparece vacio por que renombre los NaN por Desconocido.
# Out:
# Empty DataFrame
# Columns: [show_id, type, Title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Genre, Premiere, Runtime, IMDB Score, Language, original]
# Index: []

# %% [markdown]
# #### Ejercicio 20: Filtra todos los títulos que tienen información completa en las columnas 'title', 'country' y 'IMDB Score'.

# %%
completos_titulos = datos_netflix_filtros[datos_netflix_filtros['Title'].notnull()]
completos_country = datos_netflix_filtros[datos_netflix_filtros['country'].notnull()]
completos_imdb = datos_netflix_filtros[datos_netflix_filtros['IMDB Score'].notnull()]
completos_imdb
# Out:
#      show_id   type                                             Title  \
# 0         s1  Movie                              Dick Johnson Is Dead
# 141     s142  Movie                                        Extraction
# 624     s625  Movie                                        Prime Time
# 834     s835  Movie                                      Blue Miracle
# 836     s837  Movie                                         Ghost Lab
# ...      ...    ...                                               ...
# 5901   s5902  Movie                                               Tig
# 5906   s5907  Movie                       What Happened, Miss Simone?
# 5910   s5911  Movie                                  Hot Girls Wanted
# 5912   s5913  Movie  The Other One: The Long Strange Trip of Bob Weir
# 5916   s5917  Movie                                        My Own Man
#
#                            director  \
# 0                   Kirsten Johnson
# 141                Steven C. Miller
# ...

# %% [markdown]
# #### Ejercicio 21: Identifica si hay títulos duplicados en la columna 'title'.

# %%
datos_netflix_filtros[datos_netflix_filtros['Title'].duplicated()].sum()
# Out:
# show_id           0
# type              0
# Title             0
# director          0
# cast              0
# country           0
# date_added        0
# release_year      0
# rating            0
# duration          0
# listed_in         0
# description       0
# Genre             0
# Premiere          0
# Runtime         0.0
# IMDB Score      0.0
# Language          0
# original          0
# dtype: object
